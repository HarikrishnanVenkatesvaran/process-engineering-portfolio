# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "Run": [1, 2, 3, 4, 5],
    "Temperature_C": [350, 360, 355, 370, 365],
    "Yield_percent": [82, 85, 84, 88, 86]
})

plt.plot(df["Temperature_C"], df["Yield_percent"], marker="o")
plt.xlabel("Temperature (°C)")
plt.ylabel("Yield (%)")
plt.title("Yield vs Temperature")
plt.grid(True)
plt.show()
